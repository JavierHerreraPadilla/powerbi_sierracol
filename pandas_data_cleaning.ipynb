# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierHerreraPadilla/powerbi_sierracol/blob/main/pandas_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("Customer Call List (1).xlsx")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
bdf.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
df[df.duplicated(keep=False)]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 19  910 Tatooine Road, Tatooine             Yes              N
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 19               True
# 20               True

# %%
# elimnar duplicados
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# quitar columnas
df.drop(columns=["Not_Useful_Column"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-6f1bb5bbc782> in <cell line: 2>()
#       1 # quitar columnas
# ----> 2 df.drop(columns=["Not_Useful_Column"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
# df.drop("Not_Useful_Column", inplace=True, axis=1)
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# Limpiar last_name - quitar espcios vacios
df["Last_Name"].str.strip() # asi elimina espacios en blanco
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# 20      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.strip("./") #elimina . y / tano al inicio como al final
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# 20      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"] = df["Last_Name"].str.strip("./") #elimina . y / tano al inicio como al final

# %%
# Telefono
df["Phone_Number"]
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# 20    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"].str.replace("|", "")
df["Phone_Number"].str.replace("N/a", "")
df["Phone_Number"].str.replace("/", "")
df["Phone_Number"].str.replace("-", "")
# Out:
# <ipython-input-48-e20b8ff8115c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Phone_Number"].str.replace("|", "")
# 0       1235455421
# 1     123/643/9775
# 2              NaN
# 3       1235432345
# 4     876|678|3469
# 5       3047622467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9       1235455421
# 10             NaN
# 11             NaN
# 12      1235432345
# 13    876|678|3469
# 14      3047622467
# 15      1235455421
# 16    123/643/9775
# 17             NaN
# 18             N/a
# 19    876|678|3469
# 20    876|678|3469
# Name: Phone_Number, dtype: object

# %%
# Direcciones
df["Address"].str.split(",", expand=True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                   N/a           None    None
# ...

# %%
df[["Street", "state", "zip"]]= df["Address"].str.split(",", expand=True)

# %%
df.head(1)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number                Address  \
# 0        1001      Frodo   Baggins  123-545-5421  123 Shire Lane, Shire
#
#   Paying Customer Do_Not_Contact          Street   state   zip
# 0             Yes             No  123 Shire Lane   Shire  None

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes", "Y")

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No", "N")

# %%
df = df.replace("N/a", "")

# %%
df.isna().values.sum()
# Out:
# 41

# %%
df.fillna("")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter        White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df[df["Do_Not_Contact"] == "N"]
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 4         1005        Jon         Snow  876|678|3469
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# 4                 123 Dragons Road               Y              N
# ...

# %%
df[df["Do_Not_Contact"] == "N"].index
# Out:
# Int64Index([0, 4, 6, 7, 9, 10, 12, 13, 14, 15, 16, 19, 20], dtype='int64')

# %%
final_df = df.drop(df[df["Do_Not_Contact"] == "N"].index)

# %%
final_df
# Out:
#     CustomerID First_Name Last_Name  Phone_Number  \
# 1         1002       Abed     Nadir  123/643/9775
# 2         1003     Walter     White    7066950392
# 3         1004     Dwight   Schrute  123-543-2345
# 5         1006        Ron   Swanson  304-762-2467
# 8         1009    Gandalf       NaN
# 11        1012      Harry    Potter    7066950392
# 17        1018      Clark      Kent    7066950392
# 18        1019      Creed    Braton
#
#                                   Address Paying Customer Do_Not_Contact  \
# 1                     93 West Main Street              No              Y
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 5                        768 City Parkway             Yes              Y
# 8                        123 Middle Earth             Yes            NaN
# 11                   2394 Hogwarts Avenue               Y            NaN
# ...

# %%
final_df.reset_index()
# Out:
#    index  CustomerID First_Name Last_Name  Phone_Number  \
# 0      1        1002       Abed     Nadir  123/643/9775
# 1      2        1003     Walter     White    7066950392
# 2      3        1004     Dwight   Schrute  123-543-2345
# 3      5        1006        Ron   Swanson  304-762-2467
# 4      8        1009    Gandalf       NaN
# 5     11        1012      Harry    Potter    7066950392
# 6     17        1018      Clark      Kent    7066950392
# 7     18        1019      Creed    Braton
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                    93 West Main Street              No              Y
# 1                     298 Drugs Driveway               N            NaN
# 2  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 3                       768 City Parkway             Yes              Y
# 4                       123 Middle Earth             Yes            NaN
# ...

# %%
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1002       Abed     Nadir  123/643/9775
# 1        1003     Walter     White    7066950392
# 2        1004     Dwight   Schrute  123-543-2345
# 3        1006        Ron   Swanson  304-762-2467
# 4        1009    Gandalf       NaN
# 5        1012      Harry    Potter    7066950392
# 6        1018      Clark      Kent    7066950392
# 7        1019      Creed    Braton
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                    93 West Main Street              No              Y
# 1                     298 Drugs Driveway               N            NaN
# 2  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 3                       768 City Parkway             Yes              Y
# 4                       123 Middle Earth             Yes            NaN
# 5                   2394 Hogwarts Avenue               Y            NaN
# ...

# %%
final_df.to_csv("clean.csv")
